# %% [markdown]
# <a href="https://colab.research.google.com/github/jeevanraajas0210/ITA0604-Machine-Learning/blob/main/Data_Manipulation_and_indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

marks = np.array([70, 85, 60, 90, 75])

print(marks)
# Out:
# [70 85 60 90 75]

# %%
import numpy as np

marks = np.array([70, 85, 60, 90, 75])

print("Highest Mark:", np.max(marks))
# Out:
# Highest Mark: 90

# %%
import numpy as np

marks = np.array([70, 85, 60, 90, 75])

print("Lowest Mark:", np.min(marks))
# Out:
# Lowest Mark: 60

# %%
import numpy as np

marks = np.array([70, 85, 60, 90, 75])

print("Average Mark:", np.mean(marks))
# Out:
# Average Mark: 76.0

# %%
import numpy as np

marks = np.array([70, 80, 90, 60, 75])

print(marks[0])
print(marks[2])
# Out:
# 70
# 90

# %%
import numpy as np

marks = np.array([70, 80, 90, 60, 75])

print(marks[-1])
print(marks[-2])
# Out:
# 75
# 60

# %%
import numpy as np

a = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

print(a[0, 0])
print(a[1, 2])
# Out:
# 10
# 60

# %%
import numpy as np

a = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

print(a[1])
# Out:
# [40 50 60]

# %%
import numpy as np

a = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

print(a[:, 1])
# Out:
# [20 50 80]

# %%
import numpy as np

marks = np.array([70, 80, 90, 60, 75])

print(marks[1:4])
# Out:
# [80 90 60]

# %%
import numpy as np

fruits = np.array(["Apple", "Mango", "Orange", "Grapes", "Banana"])

print(fruits[0])
print(fruits[2])
print(fruits[-1])
# Out:
# Apple
# Orange
# Banana
